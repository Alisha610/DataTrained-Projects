# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing training dataset
df = pd.read_csv('bigdatamart_Train.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Filling the missing values in the train dataset
df['Item_Weight'] = df['Item_Weight'].fillna((df['Item_Weight'].mean()))
df.Outlet_Size = df.Outlet_Size.fillna("Small")

# %%
# Importing test dataset
df_test = pd.read_csv('bigdatamart_Test.csv')
df_test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df_test.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
# Filling the missing values in the test dataset
df_test['Item_Weight'] = df_test['Item_Weight'].fillna((df_test['Item_Weight'].mean()))
df_test.Outlet_Size = df_test.Outlet_Size.fillna("Small")

# %%
# Dividing the datasets into categorical and numerical data
column_num = df.select_dtypes(exclude = ["object"]).columns
column_cat = df.select_dtypes(include = ["object"]).columns

test_column_num = df_test.select_dtypes(exclude = ["object"]).columns
test_column_cat = df_test.select_dtypes(include = ["object"]).columns

# %%
df_num = df[column_num]
df_cat = df[column_cat]

df_test_num = df_test[test_column_num]
df_test_cat = df_test[test_column_cat]

# %%
df_num
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# ...

# %%
df_cat
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
df_num.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_cat.describe()
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                5                     16
# top              FDG33          Low Fat  Fruits and Vegetables
# freq                10             5089                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        8523                 8523               8523
# unique                10           3                    3                  4
# top               OUT027       Small               Tier 3  Supermarket Type1
# freq                 935        4798                 3350               5577

# %%
sns.set_palette('pastel')
# %matplotlib inline
df_num.hist(figsize=(10,8),bins=6)
plt.tight_layout()
plt.show()
#From this plot we can conclude the foll:
# Most of the MRP is in the range of 75 to 180
# Between 0 to 2000 there are around 5000 Outlet Sales
# Around 2500 items weigh between 10.0 to 13
# Most of the item visibility is between 0 to 0.05
# No outlets were established from the year 1989 to 1997

# %%
df['Outlet_Type'].value_counts(normalize=True).plot(figsize=(10,5),kind='bar')
# More than 65% of the outlet types are Supermarket Type1

# %%
df['Item_Fat_Content'].value_counts(normalize=True).plot(figsize=(10,5),kind='bar')
# Most of Item Fat Content is Low Fat

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df_test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64

# %%
vals_to_replace = {'LF':'Low Fat', 'low fat':'Low Fat', 'reg':'Regular'}
df['Item_Fat_Content'] = df['Item_Fat_Content'].map(vals_to_replace)
df_test['Item_Fat_Content'] = df_test['Item_Fat_Content'].map(vals_to_replace)

# %%
df['Item_Fat_Content'].value_counts(normalize=True).plot(figsize=(10,5),kind='bar')
# Almost 80% of Item Fat Content is Low Fat

# %%
df['Item_Type'].value_counts(normalize=True).plot(figsize=(10,5),kind='bar')
# Most of the Items are of Fruits and Vegetables and Snack Foods category

# %%
df['Outlet_Size'].value_counts(normalize=True).plot(figsize=(10,5),kind='bar')
# More than 55% of the outlets are of small size

# %%
df['Outlet_Location_Type'].value_counts(normalize=True).plot(figsize=(10,5),kind='bar')
# Almost 40% of outlets are in Tier 3 locations and almost 35% are in Tier 2 location

# %%
df['Outlet_Establishment_Year'].value_counts().plot(figsize=(10,5),kind='bar')
# Most of the outlets, i.e more than 1400, were established in the year 1985

# %%
sns.catplot(x="Outlet_Identifier", y = "Item_Outlet_Sales", data=df, height=5, aspect=2,  kind="bar")
# Outlet Sales are maximum for Outlet Identifier OUT027, more than 3500

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="Outlet_Type", y="Item_Outlet_Sales", data=df)
# Supermarket 3 has maximum outlet sales
# Grocery Store has least outlet sales

# %%
sns.boxplot(x="Outlet_Size", y="Item_Outlet_Sales", data=df)
# Medium size outlets have the most outliers, giving it potential to convert to High size

# %%
sns.boxplot(x="Item_Fat_Content", y="Item_Outlet_Sales", data=df)
# Low fat Content items have slightly more outlet sales

# %%
sns.boxplot(x="Outlet_Establishment_Year", y="Item_Outlet_Sales", data=df)
# Outlets established in the year 1985 have more outlet sales

# %%
sns.pairplot(df_num)

# %%
sns.heatmap(df_num.corr(),annot=True)
# Item Outlet sales has positive correlation with Item MRP
# Item Outlet sales has negative correlation with Item visibility

# %%
# Converting categorical data to numerical data
total_cat = df_cat.append(df_test_cat)
train_cat_len = len(df_cat)
total_cat = total_cat.drop(columns=['Item_Identifier','Outlet_Identifier'])
total_cat_num = pd.get_dummies(total_cat,drop_first=True)
df_cat = total_cat_num[:train_cat_len]
df_test_cat = total_cat_num[train_cat_len:]

# %%
df_num = df_num.drop(columns=['Outlet_Establishment_Year'])
df_test_num = df_test_num.drop(columns=['Outlet_Establishment_Year'])

# %%
# Output variable
y = df_num.iloc[:,-1]
df_num = df_num.drop(columns=['Item_Outlet_Sales'])

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
# scaling th numerical data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
train_x = sc.fit_transform(df_num)
df_num = pd.DataFrame(train_x,columns=df_num.columns)

test = sc.transform(df_test_num)
df_test_num = pd.DataFrame(test,columns=df_test_num.columns)

# %%
df_num
# Out:
#       Item_Weight  Item_Visibility  Item_MRP
# 0       -0.841872        -0.970732  1.747454
# 1       -1.641706        -0.908111 -1.489023
# 2        1.098554        -0.956917  0.010040
# 3        1.500838        -1.281758  0.660050
# 4       -0.929428        -1.281758 -1.399220
# ...           ...              ...       ...
# 8518    -1.418084        -0.181193  1.180783
# 8519    -1.059578        -0.371154 -0.527301
# 8520    -0.534243        -0.599784 -0.897208
# 8521    -1.336444         1.532880 -0.607977
# 8522     0.459634        -0.411936 -1.052261
#
# [8523 rows x 3 columns]

# %%
# Combinig train and test data
df_test = pd.concat([df_test_cat,df_test_num],axis=1)
df_train = pd.concat([df_cat,df_num],axis=1)

# %%
# Input variables
x = df_train

# %%
x
# Out:
#       Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 0                            1                         0
# 1                            0                         1
# 2                            1                         0
# 3                            0                         1
# 4                            1                         0
# ...                        ...                       ...
# 8518                         1                         0
# 8519                         0                         1
# 8520                         1                         0
# 8521                         0                         1
# 8522                         1                         0
#
#       Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Breads  \
# 0                            0                     0                 0
# 1                            0                     0                 0
# ...

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
Model_r2 = pd.DataFrame(columns = ['Model','r2 score without cross validation'])
Model_crossval = pd.DataFrame(columns = ['Model','Cross validation score'])

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso,Ridge 
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
# here we will find the random state value with which our linear model learns maximum
from sklearn import linear_model
max_r_score = 0
for r_state in range(42,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=r_state,test_size = 0.20)
    regr = linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred = regr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print('r2_score corresponding to random state ',r_state, ' is : ',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state = r_state
print('\n\n')
print('Max r2_score corresponding to state ',final_r_state, ' is : ',max_r_score)
# Out:
# r2_score corresponding to random state  42  is :  0.5771718927641476
# r2_score corresponding to random state  43  is :  0.5613486739401858
# r2_score corresponding to random state  44  is :  0.5690737343311665
# r2_score corresponding to random state  45  is :  0.5660760871752837
# r2_score corresponding to random state  46  is :  0.5422488798168696
# r2_score corresponding to random state  47  is :  0.5465890497948764
# r2_score corresponding to random state  48  is :  0.5592716419512122
# r2_score corresponding to random state  49  is :  0.5658317909571606
# r2_score corresponding to random state  50  is :  0.5611193670588923
# r2_score corresponding to random state  51  is :  0.5457205597476871
# r2_score corresponding to random state  52  is :  0.5600809780954487
# r2_score corresponding to random state  53  is :  0.5477135571132157
# r2_score corresponding to random state  54  is :  0.5746662393096393
# r2_score corresponding to random state  55  is :  0.5494126999590201
# ...

# %%
# Linear Regression model
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=112,test_size = 0.20)
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
score = r2_score(y_test,y_pred)
Model_r2 = Model_r2.append({'Model':'Linear Regression','r2 score without cross validation':score},ignore_index=True)

# Cross Validation
cross_score=cross_val_score(LinearRegression(),x,y,cv=20,scoring='r2')
cross_score.mean()
Model_crossval = Model_crossval.append({'Model':'Linear Regression','Cross validation score':cross_score.mean()},ignore_index=True)

# %%
# GridSearchCV for Lasso regression model
model_l = Lasso()
alphavalue = {'alpha':[1,0.1,0.01,0.001,0.0001]}
gd_l = GridSearchCV(estimator=model_l,param_grid=alphavalue,scoring='r2',cv=10)
gd_l.fit(x_train,y_train)
best_parameters = gd_l.best_params_
print(best_parameters)
best_result = gd_l.best_score_
print(best_result)
# Out:
# {'alpha': 1}
# 0.5514992040916795

# %%
# Lasso Regression model
ls = Lasso(alpha=1)
ls.fit(x_train,y_train)
y_pred = ls.predict(x_test)
score = r2_score(y_test,y_pred)
Model_r2 = Model_r2.append({'Model':'Lasso Regression','r2 score without cross validation':score},ignore_index=True)

# Cross Validation
cross_score=cross_val_score(Lasso(alpha=1),x,y,cv=20,scoring='r2')
cross_score.mean()
Model_crossval = Model_crossval.append({'Model':'Lasso Regression','Cross validation score':cross_score.mean()},ignore_index=True)

# %%
# GridSearchCV for Ridge regression model
model_r = Ridge()
alphavalue = {'alpha':[1,0.1,0.01,0.001,0.0001]}
gd_r = GridSearchCV(estimator=model_l,param_grid=alphavalue,scoring='r2',cv=10)
gd_r.fit(x_train,y_train)
best_parameters = gd_r.best_params_
print(best_parameters)
best_result = gd_r.best_score_
print(best_result)
# Out:
# {'alpha': 1}
# 0.5514992040916795

# %%
# Ridge Regression model
lr = Ridge(alpha=1)
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
score = r2_score(y_test,y_pred)
Model_r2 = Model_r2.append({'Model':'Ridge Regression','r2 score without cross validation':score},ignore_index=True)

# Cross Validation
cross_score=cross_val_score(Ridge(alpha=1),x,y,cv=20,scoring='r2')
cross_score.mean()
Model_crossval = Model_crossval.append({'Model':'Ridge Regression','Cross validation score':cross_score.mean()},ignore_index=True)

# %%
# GridSearchCV for SVR
svr = SVR()
grid_param = { 'kernel' : ['rbf','poly','linear','sigmoid']}
gd_sr = GridSearchCV(estimator=svr,param_grid=grid_param,scoring='r2',cv=5)
gd_sr.fit(x_train,y_train)
best_parameters = gd_sr.best_params_
print(best_parameters)
best_result = gd_sr.best_score_
print(best_result)
# Out:
# {'kernel': 'linear'}
# 0.3941928122889077

# %%
# SVR model
svr = SVR(kernel='linear')
svr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
score = r2_score(y_test,y_pred)
Model_r2 = Model_r2.append({'Model':'SVR','r2 score without cross validation':score},ignore_index=True)

# Cross Validation
cross_score=cross_val_score(SVR(kernel='linear'),x,y,cv=5,scoring='r2')
cross_score.mean()
Model_crossval = Model_crossval.append({'Model':'SVR','Cross validation score':cross_score.mean()},ignore_index=True)

# %%
# Random Forest Regressor model
rf = RandomForestRegressor(n_estimators=100,random_state=40)
rf.fit(x_train,y_train)
predrf = rf.predict(x_test)
score = r2_score(y_test,y_pred)
Model_r2 = Model_r2.append({'Model':'Random Forest Regressor','r2 score without cross validation':score},ignore_index=True)

# Cross Validation
cross_score=cross_val_score(RandomForestRegressor(n_estimators=100,random_state=40),x,y,cv=5,scoring='r2')
cross_score.mean()
Model_crossval = Model_crossval.append({'Model':'Random Forest Regressor','Cross validation score':cross_score.mean()},ignore_index=True)

# %%
# GridSearchCV for Decision Tree Regressor
dtr = DecisionTreeRegressor()
grid_param = { 'criterion' : ['mse', 'friedman_mse', 'mae']}
gd_dtr = GridSearchCV(estimator=dtr,param_grid=grid_param,scoring='r2',cv=5)
gd_dtr.fit(x_train,y_train)
best_parameters = gd_dtr.best_params_
print(best_parameters)
best_result = gd_dtr.best_score_
print(best_result)
# Out:
# {'criterion': 'friedman_mse'}
# 0.16508026490059086

# %%
# Decision Tree Regressor model
dt = DecisionTreeRegressor(criterion='friedman_mse')
rf.fit(x_train,y_train)
predrf = rf.predict(x_test)
score = r2_score(y_test,y_pred)
Model_r2 = Model_r2.append({'Model':'Decision Tree Regressor','r2 score without cross validation':score},ignore_index=True)

# Cross Validation
cross_score=cross_val_score(RandomForestRegressor(criterion='friedman_mse'),x,y,cv=5,scoring='r2')
cross_score.mean()
Model_crossval = Model_crossval.append({'Model':'Decision Tree Regressor','Cross validation score':cross_score.mean()},ignore_index=True)

# %%
Model_r2.sort_values(by='r2 score without cross validation',ascending=False,ignore_index=True)
# From this we see that Lasso model has the highest r2 score
# Out:
#                      Model  r2 score without cross validation
# 0         Lasso Regression                           0.592332
# 1        Linear Regression                           0.591035
# 2         Ridge Regression                           0.591013
# 3                      SVR                           0.591013
# 4  Random Forest Regressor                           0.591013
# 5  Decision Tree Regressor                           0.591013

# %%
Model_crossval.sort_values(by='Cross validation score',ascending=False,ignore_index=True)
# From this we see that Lasso model has the highest r2 score after cross validation
# Hence we can conclude Lasso Regression model is the best model for this dataset
# Out:
#                      Model  Cross validation score
# 0         Lasso Regression                0.557780
# 1         Ridge Regression                0.556553
# 2        Linear Regression                0.556541
# 3  Random Forest Regressor                0.536105
# 4  Decision Tree Regressor                0.535924
# 5                      SVR                0.415534

# %%
# Predicting for the test dataset using Lasso regression model
pred = ls.predict(df_test)

# %%
pred = pd.DataFrame(pred)

# %%
pred = pred.rename(columns={0: 'Item_Outlet_Sales'})

# %%
Test_predict = pd.concat([df_test,pred],axis=1)
Test_predict
# Out:
#       Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 0                            1                         0
# 1                            0                         0
# 2                            1                         0
# 3                            1                         0
# 4                            0                         1
# ...                        ...                       ...
# 5676                         0                         1
# 5677                         0                         1
# 5678                         1                         0
# 5679                         0                         1
# 5680                         0                         1
#
#       Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Breads  \
# 0                            0                     0                 0
# 1                            0                     1                 0
# ...

# %%
Test_predict.to_csv(r'Bigdatamart.csv',index=False)

# %%
df = pd.read_csv('Bigdatamart.csv')
df
# Out:
#       Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 0                            1                         0
# 1                            0                         0
# 2                            1                         0
# 3                            1                         0
# 4                            0                         1
# ...                        ...                       ...
# 5676                         0                         1
# 5677                         0                         1
# 5678                         1                         0
# 5679                         0                         1
# 5680                         0                         1
#
#       Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Breads  \
# 0                            0                     0                 0
# 1                            0                     1                 0
# ...
